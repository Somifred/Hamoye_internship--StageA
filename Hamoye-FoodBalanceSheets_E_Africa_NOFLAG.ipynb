# %% [markdown]
# ![fruits-data-hamoye.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **About the Dataset**

# %% [markdown]
# The dataset is provided by the Food and Agriculture Organization of the United Nations. The "FoodBalanceSheets_E_Africa_NOFLAG.csv" dataset compiles data on food balance sheets for East African countries. It includes details such as production, consumption, trade, and other relevant factors for various food items over the years 2014 to 2018. The dataset aims to provide insights into the food supply and demand dynamics within the East African region, aiding in assessments of food security and nutritional outcomes.
#
# The aim of analyzing the "FoodBalanceSheets_E_Africa_NOFLAG.csv" dataset is to gain insights into the food supply and demand dynamics within East African countries.

# %% [markdown]
# **Features**

# %% [markdown]
#     Area Code: This feature represents a numeric code assigned to a specific geographical area or region. It helps in uniquely identifying the area within the dataset.
#
#     Area: This feature provides the name or label of the geographical area or region corresponding to the area code. It offers a human-readable representation of the geographic location.
#
#     Item Code: An identifier assigned to a specific food item or commodity. It serves as a unique code for each distinct item in the dataset.
#
#     Item: This feature represents the name or label of the food item or commodity. It provides a human-readable description of the item corresponding to the item code.
#
#     Element Code: A numeric code that denotes a specific element or category of data related to the food item. It helps categorize the data into different types, such as production, consumption, trade, etc.
#
#     Element: This feature provides the name or label of the element or category of data related to the food item. It offers a human-readable representation of the element corresponding to the element code.
#
#     Unit: This feature specifies the unit of measurement used for the numerical data in the dataset. It indicates how quantities such as production, consumption, etc., are measured (e.g., metric tons, kilograms, etc.).
#
#     Y2014, Y2015, Y2016, Y2017, Y2018: These features represent the numerical values of the data corresponding to the years 2014, 2015, 2016, 2017, and 2018, respectively. They contain quantitative information related to the specific food item, element, and geographic area for each corresponding year.

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Load Dataset**

# %%
df = pd.read_csv("foodbalancesheets_e_africa_noflag.csv", encoding="latin-1")

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# # *Question 3*

# %%
# Define the array
array = np.array([[94, 89, 63],
                  [93, 92, 48],
                  [92, 94, 56]])

# %%
# Select the elements in bold and italics
elements_bold_italics = array[ : 2, 1 : ]
print(elements_bold_italics)
# Out:
# [[89 63]
#  [92 48]]

# %% [markdown]
# # Question 4

# %%
# Calculate the correlation between 'Element Code' and each year
correlation_2014 = df['Element Code'].corr(df['Y2014'])
correlation_2015 = df['Element Code'].corr(df['Y2015'])
correlation_2016 = df['Element Code'].corr(df['Y2016'])
correlation_2017 = df['Element Code'].corr(df['Y2017'])

# Print the correlation values for each year
print("Correlation for 2014:", correlation_2014)
print("Correlation for 2015:", correlation_2015)
print("Correlation for 2016:", correlation_2016)
print("Correlation for 2017:", correlation_2017)
# Out:
# Correlation for 2014: 0.024456819495221754
# Correlation for 2015: 0.023889199301639956
# Correlation for 2016: 0.023443997584961424
# Correlation for 2017: 0.02425400776004575

# %% [markdown]
# # Question 6

# %%
# Filter the dataset for Madagascar and Protein in 2015
filtered_df = df[(df['Area'] == 'Madagascar') & (df['Item'] == 'Protein')]

# Group by 'Area' and sum the values in 'Y2015'
sum_protein_madagascar_2015 = filtered_df.groupby('Area')['Y2015'].sum().get('Madagascar', 0)

print("Sum of Protein supply quantity in Madagascar in 2015:", sum_protein_madagascar_2015)
# Out:
# Sum of Protein supply quantity in Madagascar in 2015: 0

# %% [markdown]
# # Question 7

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
#How would you assign element 8 from the list to a variable x?
x = y[1][1]
print(x)
# Out:
# 8

# %% [markdown]
# # Question 8

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# Value to convert to percentage
Y2014_sum_null = 1589

# Convert the value to a percentage with three decimal places
percentage = Y2014_sum_null / 100

# Format the percentage to display three decimal places
percentage_str = "%.3f" % percentage

# Print the percentage
print(percentage_str)
# Out:
# 15.890

# %% [markdown]
# # Question 9

# %%
# Get the unique countries in the "Area" column
unique_countries = df["Area"].unique()

# Calculate the sum of unique countries
sum_unique_countries = len(unique_countries)

# Print the sum of unique countries
print("Sum of unique countries:", sum_unique_countries)
# Out:
# Sum of unique countries: 49

# %% [markdown]
# # Question 10

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# # Question 11

# %%
# Select columns 'Y2017' and 'Area'
selected_columns = df[['Y2017', 'Area']]

# Perform a groupby operation on 'Area' and aggregate the sum for each area in 2017
grouped_df = selected_columns.groupby('Area').sum()

# Sort the resulting DataFrame by the sum of 'Y2017' in ascending order
sorted_df = grouped_df.sort_values(by='Y2017')

# Select the area with the 7th lowest sum in 2017
seventh_lowest_area = sorted_df.index[6]

print("Area with the 7th lowest sum in 2017:", seventh_lowest_area)
# Out:
# Area with the 7th lowest sum in 2017: Guinea-Bissau

# %% [markdown]
# # QUESTION 13

# %%
highest_sum_area_2017 = df.groupby('Area')['Y2017'].sum().sort_values(ascending=False).index[0]

print("Area with the highest sum in 2017:", highest_sum_area_2017)
# Out:
# Area with the highest sum in 2017: Nigeria

# %% [markdown]
# # QUESTION 15

# %%
selected_columns = df[['Element'] + [col for col in df.columns if col.startswith('Y')]]
# Groupby 'Element' and sort by sum of each year in descending order
grouped_df = selected_columns.groupby('Element').sum().sort_values(by=list(selected_columns.columns[1:]), ascending=False)

# Get the year with the highest sum for the first element (head(1))
year_highest_variation = grouped_df.head(1).columns[1]

print("Year with the highest sum of Stock Variation:", year_highest_variation)
# Out:
# Year with the highest sum of Stock Variation: Y2015

# %% [markdown]
# # QUESTION 16

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# # QUESTION 17

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# # QUESTION 18

# %%
# Perform a groupby operation on 'Element' and aggregate the sum for each year
grouped_element = df.groupby('Element').sum()

# Get the sum of 'Processing' in 2017
sum_processing_2017 = grouped_element.loc['Processing', 'Y2017']

print("Total sum of Processing in 2017:", sum_processing_2017)
# Out:
# Total sum of Processing in 2017: 292836.0

# %% [markdown]
# # QUESTION 19

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # QUESTION 20

# %%
# Perform a groupby sum aggregation on ‘Item’ for 2015
wine_production_by_year = df.groupby('Item').agg(wine_production=('Y2015', 'sum'))

print("Total Wine production by year:")
print(wine_production_by_year.loc['Wine'])
# Out:
# Total Wine production by year:
# wine_production    4251.81
# Name: Wine, dtype: float64

# %%
# Perform a groupby sum aggregation on ‘Item’ for 2018
wine_production_by_year = df.groupby('Item').agg(wine_production=('Y2018', 'sum'))

print("Total Wine production by year:")
print(wine_production_by_year.loc['Wine'])
# Out:
# Total Wine production by year:
# wine_production    4039.32
# Name: Wine, dtype: float64
